# %%
# !pip install yfinance
# Out:
# ...
#      |████████████████████████████████| 5.5MB 6.0MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=e4e9d69d48aa9d4ca1828a5f50c02eabfcccbb20554305b882167aafbbe6e8cc
#   Stored in directory: /root/.cache/pip/wheels/f8/2a/0f/4b5a86e1d52e451757eb6bc17fd899629f0925c777741b6d04
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
from datetime import date

# %%
start_date = "2017-01-03"
end_date = date.today() #Jan 6th, 2021

# %%
techData = yf.download("AMZN FB MSFT TSLA GOOG NVDA TWTR", start=start_date, end=end_date)

# %%
financeData = yf.download("WFC BAC JPM HSBC BNP.PA CS 3988.HK", start=start_date, end=end_date)

# %%
mediaData = yf.download("NFLX NBC.BK UMGP T LGF-A DIS RELIANCE.NS", start=start_date, end=end_date)

# %%
techData.head()

# %%
financeData.head()

# %%
mediaData.head()

# %%
from google.colab import drive
drive.mount('drive')

# %%
techData.to_csv('techData.csv')
# !cp techData.csv "drive/My Drive/"

# %%
financeData.to_csv('financeData.csv')
# !cp financeData.csv "drive/My Drive/"

# %%
mediaData.to_csv('mediaData.csv')
# !cp mediaData.csv "drive/My Drive/"

# %%
start_date = "2017-01-03"
end_date = "2021-01-06"

# %%
testData = yf.download("TTM", start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
testData.to_csv('testData.csv')
# !cp testData.csv "drive/My Drive"
# Out:
# cp: cannot create regular file 'drive/My Drive': No such file or directory
